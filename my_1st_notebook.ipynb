# %% [markdown]
# <a href="https://colab.research.google.com/github/userkki/Py_Project/blob/main/my_1st_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 500)
plt.plot(x)
plt.title('A simplen graph')
plt.show()
